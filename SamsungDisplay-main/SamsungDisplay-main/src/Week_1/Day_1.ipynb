# %% [markdown]
# # 『1과목』 AI 기초 이해 및 환경 구축

# %% [markdown]
# ## 『1-1』 생성형 AI와 데이터 분석

# %% [markdown]
# ### Google Colab 명령어

# %%
# OS
# !cat /etc/issue.net
# Out:
# 'cat'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# CPU 사양
# !head /proc/cpuinfo
# Out:
# 'head'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# 메모리 사양
# !head -n 3 /proc/meminfo
# Out:
# 'head'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# !df
# Out:
# 'df'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
import sys
print(sys.version)
# Out:
# 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %% [markdown]
# ### 실습 환경 구축

# %%
3+5
# Out:
# 8

# %%
# %pwd
# Out:
# 'c:\\DEV\\SamsungDisplay\\Week_1'

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: BED0-C858
#
#  c:\DEV\SamsungDisplay\Week_1 디렉터리
#
# 2025-11-20  오후 01:16    <DIR>          .
# 2025-11-20  오후 01:16    <DIR>          ..
# 2025-11-20  오후 12:56    <DIR>          .ipynb_checkpoints
# 2025-11-04  오전 11:45    <DIR>          datasets
# 2025-11-20  오후 01:16            29,865 Day_1.ipynb
#                1개 파일              29,865 바이트
#                4개 디렉터리  10,328,510,464 바이트 남음

# %%
# %matplotlib inline

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      2.3.0
# asttokens                    3.0.0
# astunparse                   1.6.3
# beautifulsoup4               4.13.4
# blinker                      1.9.0
# certifi                      2025.4.26
# chardet                      5.2.0
# charset-normalizer           3.4.2
# click                        8.1.8
# cloudpickle                  3.1.1
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.3.2
# cycler                       0.12.1
# debugpy                      1.8.14
# decorator                    5.2.1
# et_xmlfile                   2.0.0
# exceptiongroup               1.2.2
# executing                    2.2.0
# filelock                     3.18.0
# Flask                        3.1.0
# flatbuffers                  25.2.10
# fonttools                    4.57.0
# fsspec                       2025.5.1
# gast                         0.6.0
# google-pasta                 0.2.0
# grpcio                       1.71.0
# gym                          0.25.2
# gym-notices                  0.0.8
# h5py                         3.13.0
# idna                         3.10
# imageio                      2.37.0
# ipykernel                    6.29.5
# ipython                      8.35.0
# itsdangerous                 2.2.0
# jedi                         0.19.2
# Jinja2                       3.1.6
# joblib                       1.4.2
# jpype1                       1.5.2
# jupyter_client               8.6.3
# jupyter_core                 5.7.2
# keras                        3.10.0
# kiwisolver                   1.4.8
# konlpy                       0.6.0
# libclang                     18.1.1
# lxml                         5.4.0
# Markdown                     3.8
# markdown-it-py               3.0.0
# MarkupSafe                   3.0.2
# matplotlib                   3.10.1
# matplotlib-inline            0.1.7
# mdurl                        0.1.2
# mglearn                      0.2.0
# ml_dtypes                    0.5.1
# mlxtend                      0.23.4
# mpmath                       1.3.0
# namex                        0.1.0
# nest-asyncio                 1.6.0
# networkx                     3.4.2
# numpy                        2.1.3
# openpyxl                     3.1.5
# opt_einsum                   3.4.0
# optree                       0.16.0
# packaging                    25.0
# pandas                       2.2.3
# parso                        0.8.4
# patsy                        1.0.1
# pgmpy                        1.0.0
# pillow                       11.2.1
# pip                          25.1.1
# platformdirs                 4.3.7
# prompt_toolkit               3.0.51
# protobuf                     5.29.5
# psutil                       7.0.0
# pure_eval                    0.2.3
# pygame                       2.6.1
# Pygments                     2.19.1
# pyparsing                    3.2.3
# PyQt5                        5.15.11
# PyQt5-Qt5                    5.15.2
# PyQt5_sip                    12.17.0
# pyro-api                     0.1.2
# pyro-ppl                     1.9.1
# python-dateutil              2.9.0.post0
# pytz                         2025.2
# pywin32                      310
# pyzmq                        26.4.0
# requests                     2.32.3
# rich                         14.0.0
# scikit-learn                 1.6.1
# scipy                        1.15.2
# seaborn                      0.13.2
# setuptools                   65.5.0
# six                          1.17.0
# soupsieve                    2.7
# stack-data                   0.6.3
# statsmodels                  0.14.4
# sympy                        1.14.0
# tensorboard                  2.19.0
# tensorboard-data-server      0.7.2
# tensorflow                   2.19.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    3.1.0
# threadpoolctl                3.6.0
# tk                           0.1.0
# torch                        2.7.0
# tornado                      6.4.2
# tqdm                         4.67.1
# traitlets                    5.14.3
# typing_extensions            4.13.2
# tzdata                       2025.2
# urllib3                      2.4.0
# wcwidth                      0.2.13
# Werkzeug                     3.1.3
# wheel                        0.45.1
# wordcloud                    1.9.4
# wrapt                        1.17.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print("python 버전 : {}".format(sys.version))
import numpy as np
print("numpy 버전 : {}".format(np.__version__))
import pandas as pd
print("pandas 버전 : {}".format(pd.__version__))
import matplotlib
print("matplotlib 버전 : {}".format(matplotlib.__version__))
import scipy as sp
print("scipy 버전 : {}".format(sp.__version__))
import IPython
print("IPython 버전 : {}".format(IPython.__version__))
import sklearn
print("sklearn : {}".format(sklearn.__version__))
# Out:
# python 버전 : 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]
# numpy 버전 : 2.1.3
# pandas 버전 : 2.2.3
# matplotlib 버전 : 3.10.1
# scipy 버전 : 1.15.2
# IPython 버전 : 8.35.0
# sklearn : 1.6.1

# %% [markdown]
# #### Self 점검 문제

# %%
import os
os.getcwd()
# Out:
# 'c:\\DEV\\SamsungDisplay\\Week_1'

# %%
os.chdir("C:\DEV\envs\py3_10_basic")
os.getcwd()
# Out:
# 'C:\\DEV\\envs\\py3_10_basic'

# %%
os.chdir("..")
os.getcwd()
# Out:
# 'C:\\DEV\\envs'

# %%
# %pwd
# Out:
# 'C:\\DEV\\envs'

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: BED0-C858
#
#  C:\DEV\envs 디렉터리
#
# 2025-07-02  오후 07:36    <DIR>          .
# 2025-07-02  오후 07:36    <DIR>          ..
# 2025-06-04  오전 11:05    <DIR>          mcp-env
# 2025-04-23  오후 05:02    <DIR>          py3_10_basic
# 2025-06-04  오후 05:02    <DIR>          py3_10_langchain
# 2025-06-05  오전 09:50    <DIR>          py3_10_ollama
# 2025-06-04  오후 04:27    <DIR>          py3_10_openai
# 2025-06-30  오후 06:13    <DIR>          py3_10_pt
# 2025-06-01  오후 02:21    <DIR>          py3_10_tf
# 2025-07-02  오후 07:36    <DIR>          py3_10_yolov8
#                0개 파일                   0 바이트
#               10개 디렉터리  10,327,445,504 바이트 남음

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: BED0-C858
#
#  C:\DEV\envs 디렉터리
#
# 2025-07-02  오후 07:36    <DIR>          .
# 2025-07-02  오후 07:36    <DIR>          ..
# 2025-06-04  오전 11:05    <DIR>          mcp-env
# 2025-04-23  오후 05:02    <DIR>          py3_10_basic
# 2025-06-04  오후 05:02    <DIR>          py3_10_langchain
# 2025-06-05  오전 09:50    <DIR>          py3_10_ollama
# 2025-06-04  오후 04:27    <DIR>          py3_10_openai
# 2025-06-30  오후 06:13    <DIR>          py3_10_pt
# 2025-06-01  오후 02:21    <DIR>          py3_10_tf
# 2025-07-02  오후 07:36    <DIR>          py3_10_yolov8
#                0개 파일                   0 바이트
#               10개 디렉터리  10,327,461,888 바이트 남음

# %% [markdown]
# ###  기존 접근 방식과 머신 러닝 접근 방식 비교
# ```
# 3*x + 1 계산

# %%
def f (x) :
 return 3*x + 1

x = 10
y = f(x)

print('y:', y)
# Out:
# y: 31

# %%
import tensorflow as tf
import numpy as np

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0])
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0])

model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='sgd', loss='mean_squared_error')

model.fit(xs, ys, epochs=5)

# 수정된 부분
p = model.predict(np.array([10.0]))

print('p:', p)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 105.9589
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 83.3752
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 65.6072
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 51.6280
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 40.6296
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# p: [[6.9549046]]

# %% [markdown]
# ### 하루 생산량 구하기

# %%
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

xData=[1,2,3,4,5,6,7]
yData=[25000,55000,75000,110000,128000,155000,180000]

W=tf.Variable(tf.random_uniform([1], -100, 100))
b=tf.Variable(tf.random_uniform([1], -100, 100))

X=tf.placeholder(tf.float32)
Y=tf.placeholder(tf.float32)

H=W*X+b
cost=tf.reduce_mean(tf.square(H-Y))

a=tf.Variable(0.01)
optimizer=tf.train.GradientDescentOptimizer(a)
train=optimizer.minimize(cost)
init=tf.global_variables_initializer()

sess=tf.Session()
sess.run(init)

for i in range(5001):
   sess.run(train, feed_dict={X: xData, Y: yData})
   if i % 500 ==0:
       print(i, sess.run(cost, feed_dict={X: xData, Y: yData}), sess.run(W), sess.run(b))
print(sess.run(H, feed_dict={X: [8]}))
# Out:
# WARNING:tensorflow:From C:\Users\k8s\AppData\Local\Temp\ipykernel_7736\126065017.py:3: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.
#
# WARNING:tensorflow:From c:\DEV\envs\py3_10_tf\lib\site-packages\tensorflow\python\compat\v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From C:\Users\k8s\AppData\Local\Temp\ipykernel_7736\126065017.py:18: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# 0 4609945000.0 [10346.441] [2071.758]
# 500 8687282.0 [25537.334] [1951.1134]
# 1000 8633813.0 [25627.479] [1504.7192]
# 1500 8632678.0 [25640.615] [1439.672]
# 2000 8632655.0 [25642.531] [1430.1887]
# 2500 8632649.0 [25642.805] [1428.8201]
# 3000 8632657.0 [25642.844] [1428.633]
# 3500 8632656.0 [25642.848] [1428.6133]
# 4000 8632656.0 [25642.848] [1428.6133]
# 4500 8632656.0 [25642.848] [1428.6133]
# 5000 8632656.0 [25642.848] [1428.6133]
# [206571.39]

# %% [markdown]
# ### Python Python 입력 방식

# %%
print(1+1)  # 모두 붙여쓰지 않는다.

print(1 + 1)   # 너무 많이 띄우지 않는다. 한 칸만 띄운다.
# Out:
# 2
# 2

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
if True:
    print("Answer")
    print("True")
else:
    print("Answer")
    print("False")

if True:
    print("Answer")
    print("True")
else:
        print("Answer")
    print("False")
# Out:
#   File <tokenize>:13
#     print("False")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
total = 'item_one, ' + \
        'item_two, ' + \
        'item_three'

print(total)
# Out:
# item_one, item_two, item_three

# %%
days = ['Monday', 'Tuesday',
        'Wednesday', 'Thursday', 'Friday']
print(days)
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

# %%
print (1+2)
print (1+2);
# Out:
# 3
# 3

# %%
# First comment
print("Hello, Python!")  # second comment
# last comment
# Out:
# Hello, Python!

# %%
#!/usr/bin/env python3
print("I'm excited to learn Python.")

4 + 5

print(4 + 5)

# two numbers 더 하기
x = 4
y = 5
z = x+y
print("Four plus five equals {0:d}.".format(z))
# Out:
# I'm excited to learn Python.
# 9
# Four plus five equals 9.

# %%
# two numbers 더 하기
x = 4
y = 5
z = x+y
print("Output #1: Four plus five equals {0:d}.".format(z))
# Out:
# Output #1: Four plus five equals 9.

# %%
# lists 더하기
a = [1, 2, 3, 4]
b = ["first", "second", "third", "fourth"]
c = a+b
print("Output #2: {0}, {1}, {2}".format(a, b, c))
# Out:
# Output #2: [1, 2, 3, 4], ['first', 'second', 'third', 'fourth'], [1, 2, 3, 4, 'first', 'second', 'third', 'fourth']

# %%
# lists 더하기
a = [1, 2, 3, 4]
b = ["first", "second", "third", "fourth"]
c = a+b
print("Output #3: {0}, {1}, {2}".format(a, b, c))

print("Output #4: ",a,", ",b,", ",c)
# Out:
# Output #3: [1, 2, 3, 4], ['first', 'second', 'third', 'fourth'], [1, 2, 3, 4, 'first', 'second', 'third', 'fourth']
# Output #4:  [1, 2, 3, 4] ,  ['first', 'second', 'third', 'fourth'] ,  [1, 2, 3, 4, 'first', 'second', 'third', 'fourth']

# %%
# 방법 4 (파이썬 버전 3.6 부터 가능)

age = 20
color = "빨간"
print(f"나는 {age}살이며, {color}색을 좋아해요.") # 나는 20살이며, 빨간색을 좋아해요.
# Out:
# 나는 20살이며, 빨간색을 좋아해요.

# %% [markdown]
# ### 실습 3: 비밀번호 생성

# %%
URL = "http://naver.com"
# URL = "http://daum.net"
# URL = http://google.com

http_url = URL.replace("http://", "") # 규칙 1

http_url = http_url[:http_url.index(".")] # 규칙 2
# naver.com 일 때 http_url.index(".") 의 결과는 5 이므로 위 문장은
# http_url = mystr[0:5] 와 같음

http_pass = http_url[:3] + str(len(http_url)) + str(http_url.count("e")) + "!" # 규칙 3

print("{0} 의 비밀번호는 {1} 입니다.".format(URL, http_pass))
# Out:
# http://naver.com 의 비밀번호는 nav51! 입니다.
